# %%
import json
with open ("data.json", "r", encoding = "utf-8") as file:
    data = json.load(file)

# %%
print(data)
# Out:
# {'https://genius.com/Ella-langley-choosin-texas-lyrics': {'Lyrics': 'List_of_Songs/song1.txt', 'Info': 'Song_Info/song1_info.txt'}, 'https://genius.com/Olivia-dean-man-i-need-lyrics': {'Lyrics': 'List_of_Songs/song2.txt', 'Info': 'Song_Info/song2_info.txt'}, 'https://genius.com/Bruno-mars-i-just-might-lyrics': {'Lyrics': 'List_of_Songs/song3.txt', 'Info': 'Song_Info/song3_info.txt'}, 'https://genius.com/Ella-langley-be-her-lyrics': {'Lyrics': 'List_of_Songs/song4.txt', 'Info': 'Song_Info/song4_info.txt'}, 'https://genius.com/Alex-warren-ordinary-lyrics': {'Lyrics': 'List_of_Songs/song5.txt', 'Info': 'Song_Info/song5_info.txt'}, 'https://genius.com/Olivia-dean-so-easy-to-fall-in-love-lyrics': {'Lyrics': 'List_of_Songs/song6.txt', 'Info': 'Song_Info/song6_info.txt'}, 'https://genius.com/Polskie-tumaczenia-genius-golden-huntr-x-ejae-audrey-nuna-rei-ami-and-kpop-demon-hunters-cast-polskie-tumaczenie-lyrics': {'Lyrics': 'List_of_Songs/song7.txt', 'Info': 'Song_Info/song7_info.txt'}, 'http
# ...

# %%
print(len(data))
# Out:
# 94
