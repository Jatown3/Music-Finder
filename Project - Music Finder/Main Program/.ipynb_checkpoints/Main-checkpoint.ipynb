# %%
from IPython.display import Image, display
import re
def display_results(results):
    if not results:
        print("No songs found")
        return
    print(f"\nFound {len(results)} match(es): ")

    
    for url, file_name in results:
        with open(file_name["Info"], "r", encoding = "utf-8") as f:
            info_text = f.readlines()
        for line in info_text:
            match = re.search(r"Album Art:\s*(https?://\S+)", line)
            if match:
                url = match.group(1)
                display(Image(url=url))
            else:
                print(line)

            
        print(f" Info File: {file_name["Info"]}")
        print(f" Lyrics File: {file_name["Lyrics"]}")
        print(f" Url: {url}")
        print("\n--- Lyrics ---")
        with open(file_name["Lyrics"], "r", encoding="utf-8") as f:
            print(f.read())

# %%
url = "N/A"
display(Image(url=url))
# Out:
# <img src="N/A"/>

# %%
def top_three(artist_name, song_data):
    artist_name = artist_name.lower()
    matches = []
    for url, file_name in song_data.items():
        with open(file_name["Info"], "r", encoding="utf-8") as f:
            info_text = f.read().lower()
            if "artist: " + artist_name in info_text:
                matches.append((url, file_name))
                if len(matches) == 3:
                    break
    return matches

# %%
# Jacob's Code

#Function that takes in user input title, and returns the matching song url and info (Title, artist, file with lyrics)
def find_song_title(title, song_data):
    title = title.lower()
    matches = []
#Sort through data set to find matching titles, appending url and info to 'matches' variable
    for url, info in song_data.items():
        if title in info["title"].lower():
            with open("../Song Structure/" + info["file"], "r") as l:
                lyrics = l.read()
#store lyrics
            info["lyrics"] = lyrics
            matches.append((url, info))
 #returns matches           
    return matches

# %%
## import json
songs = "songs.txt"

print("Welcome to Music Finder!")

with open("data.json", "r") as file:
    data = json.load(file)
    while True:
        print("\nWhat would you like to do?")
        print("  1. Get top 3 songs by artist name")
        print("  2. Search by song title")
        print("  3. Quit")
    
        choice = input("\nEnter choice: ")
    

    
        if choice == "1":
            artist_name = input("Enter an artist name: ")
            #Create a function that allows the user to search for the name of the artist they are looking for 
            #and give them the top three song recommendations.
            if artist_name:
                results = top_three(artist_name, data)
                display_results(results)
            else:
                print("Please enter an artist name")
    
        elif choice == "2":
            title = input("Enter a song title: ")
            if title:
                results = find_song_title(title, data)
                display_results(results)
            else:
                print("Please enter a title")
                
        elif choice == "3":
            print("Thank you for using Music Finer")
            break
            
        else:
            print("Invalid choice, please enter 1, 2, 3 or 4.")
# Out:
# Welcome to Music Finder!
#
# What would you like to do?
#   1. Get top 3 songs by artist name
#   2. Search by song title
#   3. Quit
# Enter choice:  2
# Enter a song title:  85
# No songs found
#
# What would you like to do?
#   1. Get top 3 songs by artist name
#   2. Search by song title
#   3. Quit
# Enter choice:  e85
# Invalid choice, please enter 1, 2, 3 or 4.
#
# What would you like to do?
#   1. Get top 3 songs by artist name
#   2. Search by song title
#   3. Quit
# Enter choice:  2
# Enter a song title:  e85
# Found 1 match(es):
# ===Song Information===
#
#
#
# Song: E85
#
# Artist: Don Toliver
#
# Album: OCTANE (Digital Deluxe)
# <img src="https://images.genius.com/a543e958de68ca56bcfb20b8ed23c690.1000x1000x1.jpg"/>
#  Info File: Song_Info/song23_info.txt
#  Lyrics File: List_of_Songs/song23.txt
#  Url: https://images.genius.com/a543e958de68ca56bcfb20b8ed23c690.1000x1000x1.jpg
#
# --- Lyrics ---
# [Intro: Don Toliver & Malcolm Todd]
# (
# I love
# )
# (
# I've been tryin',
# tryin
# ', tryin',
# tryin
# '
# )
# (
# I've been cryin', cryin', cry—
# )
# On the highway and I'm thinkin' that I love her
# On the highway and I'm thinkin' there ain't no rubber
# On the highway with my significant lover (
# I love
# )
# (I've been tryin', tryin', tryin', tryin')
# High octane, more fuel for your consumption, nigga
# More 'tane for the vein, nigga (I've been cryin', cryin', cry—)
# It's lit, yeah
#
# [Chorus: Don Toliver]
# On the highway and I'm thinkin' that I love her
# On the highway and I'm thinkin' there ain't no rubber
# On the highway with my significant lover (It go)
# (It go, it go)
# You been runnin' the summer, you got a brand-new Hummer
# We laugh all day like Dumber and Dumber
# I'm 'bout to shoot my shot, she lovin' my jumper
# My favoritе outfit is her see-through romper
#
# [Verse: Don Toliver & Malcolm Todd]
# Don't worry, I got you, I promise I won't hurt hеr
# She talk like a snappin' turtle, she squirt like that shit fertile
# Got drink in my cup, on Kirko, she move that ass in circles
# Not sippin' on green, it's purple, we said that shit never hurt, though
# I just hope you down for me (I've been tryin', tryin')
# 'Cause this shit what it supposed to be (
# I love
# )
#
# [Chorus: Don Toliver & Malcolm Todd]
# On the highway and I'm thinkin' that I love her
# On the highway and I'm thinkin' there ain't no rubber
# On the highway with my significant lover (It go)
# (It go, it go)
# You been runnin' the summer, you got a brand-new Hummer
# We laugh all day like Dumber and Dumber
# I'm 'bout to shoot my shot, she lovin' my jumper
# My favorite outfit is her see-through romper (
# I love
# )
#
# [Outro]
# I've been tryin', tryin', tryin', tryin'
# I've been cryin', cryin', cry—
#
# What would you like to do?
#   1. Get top 3 songs by artist name
#   2. Search by song title
#   3. Quit
